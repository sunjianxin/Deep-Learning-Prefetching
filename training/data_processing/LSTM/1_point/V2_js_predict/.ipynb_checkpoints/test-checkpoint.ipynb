# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import interactive
interactive(True)
# %matplotlib qt

# %%
# Using readlines()
file1 = open('predict_test3.txt', 'r')
Lines = file1.readlines() 

line_x = Lines[0][:-1].split(' ')
line_y = Lines[1][:-1].split(' ')
line_z = Lines[2][:-1].split(' ')

x = [float(i) for i in line_x]
y = [float(i) for i in line_y]
z = [float(i) for i in line_z]

# %%
f = open('predict_test3.csv')
df = pd.read_csv(f)
x_ = np.array(df['x']).tolist()
y_ = np.array(df['y']).tolist()
z_ = np.array(df['z']).tolist()

# %%
x
# Out:
# [-0.502926,
#  -0.502926,
#  -0.7241479999999999,
#  -1.0199132,
#  -1.0537503,
#  -1.0149727,
#  -0.92892575,
#  -0.7877048,
#  -0.595042,
#  -0.40572453,
#  -0.15647858,
#  0.20321271,
#  0.08676614,
#  -0.5706235,
#  -0.8854724,
#  -1.0910646,
#  -1.0175626,
#  -0.5548469,
#  1.434203,
#  1.4407132,
#  0.6454104,
#  -0.61251867,
#  0.30605677,
#  1.1399132,
#  1.1625303,
#  1.0380243,
#  0.948604,
#  0.8871614,
#  0.8416629,
#  0.8052205,
#  0.904282,
#  1.021264,
#  1.1692591,
#  1.2932674,
#  1.2932407,
#  1.0648615,
#  0.886855,
#  0.7330649,
#  0.5345659,
#  -1.5965445,
#  -1.380186,
#  -1.2015357,
#  -1.26017,
#  -1.325443,
#  -1.4025508,
#  -1.4558542,
#  -1.4858272,
#  -1.495623,
#  -1.4668801,
#  -1.3977592,
#  -1.3129228,
#  -1.1950893,
#  -1.0262204,
#  -0.84462893,
#  -0.6575054,
#  -0.46821687,
#  -0.2768688,
#  -0.07857826,
#  0.16465475,
#  -0.10085273,
#  -0.4817753,
#  -0.7045951,
#  -0.84152126,
#  -0.98123646,
#  -1.1144232,
#  -1.2311072,
#  -1.3235531,
# ...

# %%
x_
# Out:
# [-0.502926,
#  -0.502926,
#  -0.7241479999999999,
#  -1.01991,
#  -1.05375,
#  -1.0149700000000001,
#  -0.928926,
#  -0.787705,
#  -0.595042,
#  -0.405725,
#  -0.156479,
#  0.203213,
#  0.08676610000000001,
#  -0.570624,
#  -0.8854719999999999,
#  -1.0910600000000001,
#  -1.01756,
#  -0.554847,
#  1.4342,
#  1.44071,
#  0.645411,
#  -0.6125189999999999,
#  0.306057,
#  1.13991,
#  1.1625299999999998,
#  1.0380200000000002,
#  0.9486040000000001,
#  0.8871610000000001,
#  0.8416629999999999,
#  0.807095,
#  0.9042819999999999,
#  1.02126,
#  1.16926,
#  1.2932700000000001,
#  1.29324,
#  1.0648600000000001,
#  0.886855,
#  0.733065,
#  0.534566,
#  -1.51427,
#  -1.38019,
#  -1.20154,
#  -1.26017,
#  -1.32544,
#  -1.40255,
#  -1.45585,
#  -1.48583,
#  -1.4956200000000002,
#  -1.46688,
#  -1.3977600000000001,
#  -1.31292,
#  -1.19509,
#  -1.0262200000000001,
#  -0.8446290000000001,
#  -0.657505,
#  -0.468217,
#  -0.27686900000000003,
#  -0.0785783,
#  0.164655,
#  -0.100853,
# ...

# %%
plt.plot(x, label='org')
plt.plot(x_, label='back')
plt.legend()
