# %%
# visuialy analysis training results by see the learning curve

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import interactive
interactive(True)
# %matplotlib qt

# %%
# training learning curve
train_loss_w1 = np.load('1600/with_normalization/window_1/train_loss.npy')
train_loss_w2 = np.load('1600/with_normalization/window_2/train_loss.npy')
train_loss_w3 = np.load('1600/with_normalization/window_3/train_loss.npy')
train_loss_w4 = np.load('1600/with_normalization/window_4/train_loss.npy')
train_loss_w5 = np.load('1600/with_normalization/window_5/train_loss.npy')
train_loss_w6 = np.load('1600/with_normalization/window_6/train_loss.npy')
train_loss_w7 = np.load('1600/with_normalization/window_7/train_loss.npy')
train_loss_w8 = np.load('1600/with_normalization/window_8/train_loss.npy')
train_loss_w9 = np.load('1600/with_normalization/window_9/train_loss.npy')
train_loss_w10 = np.load('1600/with_normalization/window_10/train_loss.npy')
# train_loss_w5 = np.load('1600/window_5/train_loss.npy', np.asarray(train_loss))

starting_epoch = 1550
end_epoch = 1600
# train_loss_curve_w1, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w1[starting_epoch:end_epoch])
train_loss_curve_w2, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w2[starting_epoch:end_epoch])
train_loss_curve_w3, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w3[starting_epoch:end_epoch])
train_loss_curve_w4, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w4[starting_epoch:end_epoch])
train_loss_curve_w5, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w5[starting_epoch:end_epoch])
train_loss_curve_w6, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w6[starting_epoch:end_epoch])
train_loss_curve_w7, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w7[starting_epoch:end_epoch])
train_loss_curve_w8, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w8[starting_epoch:end_epoch])
train_loss_curve_w9, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w9[starting_epoch:end_epoch])
train_loss_curve_w10, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w10[starting_epoch:end_epoch])

# valid_loss_curve, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss[starting_epoch:end_epoch])
# test_loss_curve_1, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_1[starting_epoch:end_epoch])
# test_loss_curve_2, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_2[starting_epoch:end_epoch])
# test_loss_curve_3, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_3[starting_epoch:end_epoch])
# test_loss_curve_4, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_4[starting_epoch:end_epoch])
# test_loss_curve_5, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_5[starting_epoch:end_epoch])
plt.legend([# train_loss_curve_w1,
            train_loss_curve_w2,
            train_loss_curve_w3,
            train_loss_curve_w4,
            train_loss_curve_w5,
            train_loss_curve_w6,
            train_loss_curve_w7,
            train_loss_curve_w8,
            train_loss_curve_w9,
            train_loss_curve_w10], [# 'Train Loss w 1',
                                    'Train Loss w 2',
                                    'Train Loss w 3',
                                    'Train Loss w 4',
                                    'Train Loss w 5',
                                    'Train Loss w 6',
                                    'Train Loss w 7',
                                    'Train Loss w 8',
                                    'Train Loss w 9',
                                    'Train Loss w 10'])
plt.grid()
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")

# %%
# validation learning curve (not that useful)
valid_loss_w1 = np.load('1600/with_normalization/window_1/valid_loss.npy')
valid_loss_w2 = np.load('1600/with_normalization/window_2/valid_loss.npy')
valid_loss_w3 = np.load('1600/with_normalization/window_3/valid_loss.npy')
valid_loss_w4 = np.load('1600/with_normalization/window_4/valid_loss.npy')
valid_loss_w5 = np.load('1600/with_normalization/window_5/valid_loss.npy')
valid_loss_w6 = np.load('1600/with_normalization/window_6/valid_loss.npy')
valid_loss_w7 = np.load('1600/with_normalization/window_7/valid_loss.npy')
valid_loss_w8 = np.load('1600/with_normalization/window_8/valid_loss.npy')
valid_loss_w9 = np.load('1600/with_normalization/window_9/valid_loss.npy')
valid_loss_w10 = np.load('1600/with_normalization/window_10/valid_loss.npy')
# valid_loss_w5 = np.load('1600/window_5/valid_loss.npy', np.asarray(valid_loss))


starting_epoch = 1550
end_epoch = 1600
valid_loss_curve_w1, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w1[starting_epoch:end_epoch])
valid_loss_curve_w2, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w2[starting_epoch:end_epoch])
valid_loss_curve_w3, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w3[starting_epoch:end_epoch])
valid_loss_curve_w4, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w4[starting_epoch:end_epoch])
valid_loss_curve_w5, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w5[starting_epoch:end_epoch])
valid_loss_curve_w6, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w6[starting_epoch:end_epoch])
valid_loss_curve_w7, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w7[starting_epoch:end_epoch])
valid_loss_curve_w8, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w8[starting_epoch:end_epoch])
valid_loss_curve_w9, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w9[starting_epoch:end_epoch])
valid_loss_curve_w10, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w10[starting_epoch:end_epoch])

# valid_loss_curve, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss[starting_epoch:end_epoch])
# test_loss_curve_1, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_1[starting_epoch:end_epoch])
# test_loss_curve_2, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_2[starting_epoch:end_epoch])
# test_loss_curve_3, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_3[starting_epoch:end_epoch])
# test_loss_curve_4, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_4[starting_epoch:end_epoch])
# test_loss_curve_5, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_5[starting_epoch:end_epoch])
plt.legend([valid_loss_curve_w1,
            valid_loss_curve_w2,
            valid_loss_curve_w3,
            valid_loss_curve_w4,
            valid_loss_curve_w5,
            valid_loss_curve_w6,
            valid_loss_curve_w7,
            valid_loss_curve_w8,
            valid_loss_curve_w9,
            valid_loss_curve_w10], ['valid Loss w 1',
                                    'valid Loss w 2',
                                    'valid Loss w 3',
                                    'valid Loss w 4',
                                    'valid Loss w 5',
                                    'valid Loss w 6',
                                    'valid Loss w 7',
                                    'valid Loss w 8',
                                    'valid Loss w 9',
                                    'valid Loss w 10'])
plt.grid()
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")

# %%
# test 1 dataset learning curve, test 1 will be used as validation data set
test_loss_w1 = np.load('1600/with_normalization/window_1/test_loss_5.npy')
test_loss_w2 = np.load('1600/with_normalization/window_2/test_loss_5.npy')
test_loss_w3 = np.load('1600/with_normalization/window_3/test_loss_5.npy')
test_loss_w4 = np.load('1600/with_normalization/window_4/test_loss_5.npy')
test_loss_w5 = np.load('1600/with_normalization/window_5/test_loss_5.npy')
test_loss_w6 = np.load('1600/with_normalization/window_6/test_loss_5.npy')
test_loss_w7 = np.load('1600/with_normalization/window_7/test_loss_5.npy')
test_loss_w8 = np.load('1600/with_normalization/window_8/test_loss_5.npy')
test_loss_w9 = np.load('1600/with_normalization/window_9/test_loss_5.npy')
test_loss_w10 = np.load('1600/with_normalization/window_10/test_loss_5.npy')
# test_loss_w5 = np.load('1600/window_5/test_loss.npy', np.asarray(test_loss))


starting_epoch = 100
end_epoch = 1600
plt.figure(figsize=(12,8))
test_loss_curve_w1, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w1[starting_epoch:end_epoch])
test_loss_curve_w2, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w2[starting_epoch:end_epoch])
test_loss_curve_w3, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w3[starting_epoch:end_epoch])
test_loss_curve_w4, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w4[starting_epoch:end_epoch])
test_loss_curve_w5, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w5[starting_epoch:end_epoch])
test_loss_curve_w6, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w6[starting_epoch:end_epoch])
test_loss_curve_w7, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w7[starting_epoch:end_epoch])
test_loss_curve_w8, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w8[starting_epoch:end_epoch])
test_loss_curve_w9, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w9[starting_epoch:end_epoch])
test_loss_curve_w10, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w10[starting_epoch:end_epoch])


# test_loss_curve, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss[starting_epoch:end_epoch])
# test_loss_curve_1, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_1[starting_epoch:end_epoch])
# test_loss_curve_2, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_2[starting_epoch:end_epoch])
# test_loss_curve_3, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_3[starting_epoch:end_epoch])
# test_loss_curve_4, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_4[starting_epoch:end_epoch])
# test_loss_curve_5, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_5[starting_epoch:end_epoch])

leg = plt.legend([test_loss_curve_w1,
            test_loss_curve_w2,
            test_loss_curve_w3,
            test_loss_curve_w4,
            test_loss_curve_w5,
            test_loss_curve_w6,
            test_loss_curve_w7,
            test_loss_curve_w8,
            test_loss_curve_w9,
            test_loss_curve_w10], ['Size 1',
                                    'Size 2',
                                    'Size 3',
                                    'Size 4',
                                    'Size 5',
                                    'Size 6',
                                    'Size 7',
                                    'Size 8',
                                    'Size 9',
                                    'Size 10'], prop={'size': 16}, ncol=2)

for legobj in leg.legendHandles:
    legobj.set_linewidth(4.0)
    
plt.grid()
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("MSE Loss", fontsize=18)

# %%
# training learning curve
train_loss_w1 = np.load('1600/without_normalization/window_1/train_loss.npy')
train_loss_w2 = np.load('1600/without_normalization/window_2/train_loss.npy')
train_loss_w3 = np.load('1600/without_normalization/window_3/train_loss.npy')
train_loss_w4 = np.load('1600/without_normalization/window_4/train_loss.npy')
train_loss_w5 = np.load('1600/without_normalization/window_5/train_loss.npy')
train_loss_w6 = np.load('1600/without_normalization/window_6/train_loss.npy')
train_loss_w7 = np.load('1600/without_normalization/window_7/train_loss.npy')
train_loss_w8 = np.load('1600/without_normalization/window_8/train_loss.npy')
train_loss_w9 = np.load('1600/without_normalization/window_9/train_loss.npy')
# train_loss_w10 = np.load('1600/without_normalization/window_10/train_loss.npy')
# train_loss_w5 = np.load('1600/window_5/train_loss.npy', np.asarray(train_loss))

starting_epoch = 30
end_epoch = 1600
train_loss_curve_w1, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w1[starting_epoch:end_epoch])
train_loss_curve_w2, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w2[starting_epoch:end_epoch])
train_loss_curve_w3, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w3[starting_epoch:end_epoch])
train_loss_curve_w4, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w4[starting_epoch:end_epoch])
train_loss_curve_w5, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w5[starting_epoch:end_epoch])
train_loss_curve_w6, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w6[starting_epoch:end_epoch])
train_loss_curve_w7, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w7[starting_epoch:end_epoch])
train_loss_curve_w8, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w8[starting_epoch:end_epoch])
train_loss_curve_w9, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w9[starting_epoch:end_epoch])
# train_loss_curve_w10, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w10[starting_epoch:end_epoch])

# valid_loss_curve, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss[starting_epoch:end_epoch])
# test_loss_curve_1, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_1[starting_epoch:end_epoch])
# test_loss_curve_2, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_2[starting_epoch:end_epoch])
# test_loss_curve_3, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_3[starting_epoch:end_epoch])
# test_loss_curve_4, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_4[starting_epoch:end_epoch])
# test_loss_curve_5, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_5[starting_epoch:end_epoch])
plt.legend([train_loss_curve_w1,
            train_loss_curve_w2,
            train_loss_curve_w3,
            train_loss_curve_w4,
            train_loss_curve_w5,
            train_loss_curve_w6,
            train_loss_curve_w7,
            train_loss_curve_w8,
            train_loss_curve_w9,
            train_loss_curve_w10], ['Train Loss w 1',
                                    'Train Loss w 2',
                                    'Train Loss w 3',
                                    'Train Loss w 4',
                                    'Train Loss w 5',
                                    'Train Loss w 6',
                                    'Train Loss w 7',
                                    'Train Loss w 8',
                                    'Train Loss w 9',
                                    'Train Loss w 10'])
plt.grid()
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")

# %%
# validation learning curve (not that useful)
valid_loss_w1 = np.load('1600/without_normalization/window_1/valid_loss.npy')
valid_loss_w2 = np.load('1600/without_normalization/window_2/valid_loss.npy')
valid_loss_w3 = np.load('1600/without_normalization/window_3/valid_loss.npy')
valid_loss_w4 = np.load('1600/without_normalization/window_4/valid_loss.npy')
valid_loss_w5 = np.load('1600/without_normalization/window_5/valid_loss.npy')
valid_loss_w6 = np.load('1600/without_normalization/window_6/valid_loss.npy')
valid_loss_w7 = np.load('1600/without_normalization/window_7/valid_loss.npy')
valid_loss_w8 = np.load('1600/without_normalization/window_8/valid_loss.npy')
valid_loss_w9 = np.load('1600/without_normalization/window_9/valid_loss.npy')
# valid_loss_w10 = np.load('1600/without_normalization/window_10/valid_loss.npy')
# valid_loss_w5 = np.load('1600/window_5/valid_loss.npy', np.asarray(valid_loss))


starting_epoch = 30
end_epoch = 1600
valid_loss_curve_w1, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w1[starting_epoch:end_epoch])
valid_loss_curve_w2, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w2[starting_epoch:end_epoch])
valid_loss_curve_w3, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w3[starting_epoch:end_epoch])
valid_loss_curve_w4, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w4[starting_epoch:end_epoch])
valid_loss_curve_w5, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w5[starting_epoch:end_epoch])
valid_loss_curve_w6, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w6[starting_epoch:end_epoch])
valid_loss_curve_w7, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w7[starting_epoch:end_epoch])
valid_loss_curve_w8, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w8[starting_epoch:end_epoch])
valid_loss_curve_w9, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w9[starting_epoch:end_epoch])
# valid_loss_curve_w10, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss_w10[starting_epoch:end_epoch])

# valid_loss_curve, = plt.plot(list(range(starting_epoch, end_epoch)), valid_loss[starting_epoch:end_epoch])
# test_loss_curve_1, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_1[starting_epoch:end_epoch])
# test_loss_curve_2, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_2[starting_epoch:end_epoch])
# test_loss_curve_3, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_3[starting_epoch:end_epoch])
# test_loss_curve_4, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_4[starting_epoch:end_epoch])
# test_loss_curve_5, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_5[starting_epoch:end_epoch])
plt.legend([valid_loss_curve_w1,
            valid_loss_curve_w2,
            valid_loss_curve_w3,
            valid_loss_curve_w4,
            valid_loss_curve_w5,
            valid_loss_curve_w6,
            valid_loss_curve_w7,
            valid_loss_curve_w8,
            valid_loss_curve_w9,
            valid_loss_curve_w10], ['valid Loss w 1',
                                    'valid Loss w 2',
                                    'valid Loss w 3',
                                    'valid Loss w 4',
                                    'valid Loss w 5',
                                    'valid Loss w 6',
                                    'valid Loss w 7',
                                    'valid Loss w 8',
                                    'valid Loss w 9',
                                    'valid Loss w 10'])
plt.grid()
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")

# %%
# test 1 dataset learning curve, test 1 will be used as validation data set
test_loss_w1 = np.load('1600/without_normalization/window_1/test_loss_1.npy')
test_loss_w2 = np.load('1600/without_normalization/window_2/test_loss_1.npy')
test_loss_w3 = np.load('1600/without_normalization/window_3/test_loss_1.npy')
test_loss_w4 = np.load('1600/without_normalization/window_4/test_loss_1.npy')
test_loss_w5 = np.load('1600/without_normalization/window_5/test_loss_1.npy')
test_loss_w6 = np.load('1600/without_normalization/window_6/test_loss_1.npy')
test_loss_w7 = np.load('1600/without_normalization/window_7/test_loss_1.npy')
test_loss_w8 = np.load('1600/without_normalization/window_8/test_loss_1.npy')
test_loss_w9 = np.load('1600/without_normalization/window_9/test_loss_1.npy')
# test_loss_w10 = np.load('1600/without_normalization/window_10/test_loss_1.npy')
# test_loss_w5 = np.load('1600/window_5/test_loss.npy', np.asarray(test_loss))


starting_epoch = 100
end_epoch = 1600
plt.figure(figsize=(12,8))
test_loss_curve_w1, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w1[starting_epoch:end_epoch])
test_loss_curve_w2, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w2[starting_epoch:end_epoch])
test_loss_curve_w3, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w3[starting_epoch:end_epoch])
test_loss_curve_w4, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w4[starting_epoch:end_epoch])
test_loss_curve_w5, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w5[starting_epoch:end_epoch])
test_loss_curve_w6, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w6[starting_epoch:end_epoch])
test_loss_curve_w7, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w7[starting_epoch:end_epoch])
test_loss_curve_w8, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w8[starting_epoch:end_epoch])
test_loss_curve_w9, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w9[starting_epoch:end_epoch])
# test_loss_curve_w10, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_w10[starting_epoch:end_epoch])


# test_loss_curve, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss[starting_epoch:end_epoch])
# test_loss_curve_1, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_1[starting_epoch:end_epoch])
# test_loss_curve_2, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_2[starting_epoch:end_epoch])
# test_loss_curve_3, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_3[starting_epoch:end_epoch])
# test_loss_curve_4, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_4[starting_epoch:end_epoch])
# test_loss_curve_5, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_5[starting_epoch:end_epoch])

leg = plt.legend([test_loss_curve_w1,
            test_loss_curve_w2,
            test_loss_curve_w3,
            test_loss_curve_w4,
            test_loss_curve_w5,
            test_loss_curve_w6,
            test_loss_curve_w7,
            test_loss_curve_w8,
            test_loss_curve_w9,
            test_loss_curve_w10], ['Size 1',
                                    'Size 2',
                                    'Size 3',
                                    'Size 4',
                                    'Size 5',
                                    'Size 6',
                                    'Size 7',
                                    'Size 8',
                                    'Size 9',
                                    'Size 10'], prop={'size': 16}, ncol=2)

for legobj in leg.legendHandles:
    legobj.set_linewidth(4.0)
    
plt.grid()
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("MSE Loss", fontsize=18)

# %%
# test 1 dataset learning curve, test 1 will be used as validation data set
test_loss_w1 = np.load('1600/with_normalization_with_earlystop/window_1/test_loss_1.npy')
test_loss_w2 = np.load('1600/with_normalization_with_earlystop/window_2/test_loss_1.npy')
test_loss_w3 = np.load('1600/with_normalization_with_earlystop/window_3/test_loss_1.npy')
test_loss_w4 = np.load('1600/with_normalization_with_earlystop/window_4/test_loss_1.npy')
test_loss_w5 = np.load('1600/with_normalization_with_earlystop/window_5/test_loss_1.npy')
test_loss_w6 = np.load('1600/with_normalization_with_earlystop/window_6/test_loss_1.npy')
test_loss_w7 = np.load('1600/with_normalization_with_earlystop/window_7/test_loss_1.npy')
test_loss_w8 = np.load('1600/with_normalization_with_earlystop/window_8/test_loss_1.npy')
test_loss_w9 = np.load('1600/with_normalization_with_earlystop/window_9/test_loss_1.npy')
test_loss_w10 = np.load('1600/with_normalization_with_earlystop/window_10/test_loss_1.npy')
# test_loss_w5 = np.load('1600/window_5/test_loss.npy', np.asarray(test_loss))

file1 = open('model/with_early_stop_after_400/model_w_1.txt', 'r')
Lines = file1.readlines()[0].split(' ')
end_epoch = int(Lines[-1])


starting_epoch = 100
# end_epoch = 1600
plt.figure(figsize=(12,8))
test_loss_curve_w1, = plt.plot(list(range(starting_epoch, len(test_loss_w1))), test_loss_w1[starting_epoch:])
test_loss_curve_w2, = plt.plot(list(range(starting_epoch, len(test_loss_w2))), test_loss_w2[starting_epoch:])
test_loss_curve_w3, = plt.plot(list(range(starting_epoch, len(test_loss_w3))), test_loss_w3[starting_epoch:])
test_loss_curve_w4, = plt.plot(list(range(starting_epoch, len(test_loss_w4))), test_loss_w4[starting_epoch:])
test_loss_curve_w5, = plt.plot(list(range(starting_epoch, len(test_loss_w5))), test_loss_w5[starting_epoch:])
test_loss_curve_w6, = plt.plot(list(range(starting_epoch, len(test_loss_w6))), test_loss_w6[starting_epoch:])
test_loss_curve_w7, = plt.plot(list(range(starting_epoch, len(test_loss_w7))), test_loss_w7[starting_epoch:])
test_loss_curve_w8, = plt.plot(list(range(starting_epoch, len(test_loss_w8))), test_loss_w8[starting_epoch:])
test_loss_curve_w9, = plt.plot(list(range(starting_epoch, len(test_loss_w9))), test_loss_w9[starting_epoch:])
test_loss_curve_w10, = plt.plot(list(range(starting_epoch, len(test_loss_w10))), test_loss_w10[starting_epoch:])

# test_loss_curve_w1, = plt.plot(test_loss_w1[starting_epoch:])
# test_loss_curve_w2, = plt.plot(test_loss_w2[starting_epoch:])
# test_loss_curve_w3, = plt.plot(test_loss_w3[starting_epoch:])
# test_loss_curve_w4, = plt.plot(test_loss_w4[starting_epoch:])
# test_loss_curve_w5, = plt.plot(test_loss_w5[starting_epoch:])
# test_loss_curve_w6, = plt.plot(test_loss_w6[starting_epoch:])
# test_loss_curve_w7, = plt.plot(test_loss_w7[starting_epoch:])
# test_loss_curve_w8, = plt.plot(test_loss_w8[starting_epoch:])
# test_loss_curve_w9, = plt.plot(test_loss_w9[starting_epoch:])
# test_loss_curve_w10, = plt.plot(test_loss_w10[starting_epoch:])


# test_loss_curve, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss[starting_epoch:end_epoch])
# test_loss_curve_1, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_1[starting_epoch:end_epoch])
# test_loss_curve_2, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_2[starting_epoch:end_epoch])
# test_loss_curve_3, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_3[starting_epoch:end_epoch])
# test_loss_curve_4, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_4[starting_epoch:end_epoch])
# test_loss_curve_5, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_5[starting_epoch:end_epoch])

leg = plt.legend([test_loss_curve_w1,
            test_loss_curve_w2,
            test_loss_curve_w3,
            test_loss_curve_w4,
            test_loss_curve_w5,
            test_loss_curve_w6,
            test_loss_curve_w7,
            test_loss_curve_w8,
            test_loss_curve_w9,
            test_loss_curve_w10], ['Size 1',
                                    'Size 2',
                                    'Size 3',
                                    'Size 4',
                                    'Size 5',
                                    'Size 6',
                                    'Size 7',
                                    'Size 8',
                                    'Size 9',
                                    'Size 10'], prop={'size': 16}, ncol=2)

for legobj in leg.legendHandles:
    legobj.set_linewidth(4.0)
    
plt.grid()
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("MSE Loss", fontsize=18)

# %%
# test 1 dataset learning curve, test 1 will be used as validation data set
test_loss_w1 = np.load('1600/with_normalization_with_earlystop/window_1/test_loss_1.npy')
test_loss_w2 = np.load('1600/with_normalization_with_earlystop/window_2/test_loss_1.npy')
test_loss_w3 = np.load('1600/with_normalization_with_earlystop/window_3/test_loss_1.npy')
test_loss_w4 = np.load('1600/with_normalization_with_earlystop/window_4/test_loss_1.npy')
test_loss_w5 = np.load('1600/with_normalization_with_earlystop/window_5/test_loss_1.npy')
test_loss_w6 = np.load('1600/with_normalization_with_earlystop/window_6/test_loss_1.npy')
test_loss_w7 = np.load('1600/with_normalization_with_earlystop/window_7/test_loss_1.npy')
test_loss_w8 = np.load('1600/with_normalization_with_earlystop/window_8/test_loss_1.npy')
test_loss_w9 = np.load('1600/with_normalization_with_earlystop/window_9/test_loss_1.npy')
test_loss_w10 = np.load('1600/with_normalization_with_earlystop/window_10/test_loss_1.npy')
# test_loss_w5 = np.load('1600/window_5/test_loss.npy', np.asarray(test_loss))

file = open('model/with_early_stop_after_400/model_w_1.txt', 'r')
end_epoch_1 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model/with_early_stop_after_400/model_w_2.txt', 'r')
end_epoch_2 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model/with_early_stop_after_400/model_w_3.txt', 'r')
end_epoch_3 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model/with_early_stop_after_400/model_w_4.txt', 'r')
end_epoch_4 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model/with_early_stop_after_400/model_w_5.txt', 'r')
end_epoch_5 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model/with_early_stop_after_400/model_w_6.txt', 'r')
end_epoch_6 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model/with_early_stop_after_400/model_w_7.txt', 'r')
end_epoch_7 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model/with_early_stop_after_400/model_w_8.txt', 'r')
end_epoch_8 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model/with_early_stop_after_400/model_w_9.txt', 'r')
end_epoch_9 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model/with_early_stop_after_400/model_w_10.txt', 'r')
end_epoch_10 = int(file.readlines()[0].split(' ')[-1])
file.close()


starting_epoch = 10
# end_epoch = 1600
plt.figure(figsize=(12,8))
test_loss_curve_w1, = plt.plot(list(range(starting_epoch, end_epoch_1 + 1)), test_loss_w1[starting_epoch:end_epoch_1 + 1])
test_loss_curve_w2, = plt.plot(list(range(starting_epoch, end_epoch_2 + 1)), test_loss_w2[starting_epoch:end_epoch_2 + 1])
test_loss_curve_w3, = plt.plot(list(range(starting_epoch, end_epoch_3 + 1)), test_loss_w3[starting_epoch:end_epoch_3 + 1])
test_loss_curve_w4, = plt.plot(list(range(starting_epoch, end_epoch_4 + 1)), test_loss_w4[starting_epoch:end_epoch_4 + 1])
test_loss_curve_w5, = plt.plot(list(range(starting_epoch, end_epoch_5 + 1)), test_loss_w5[starting_epoch:end_epoch_5 + 1])
test_loss_curve_w6, = plt.plot(list(range(starting_epoch, end_epoch_6 + 1)), test_loss_w6[starting_epoch:end_epoch_6 + 1])
test_loss_curve_w7, = plt.plot(list(range(starting_epoch, end_epoch_7 + 1)), test_loss_w7[starting_epoch:end_epoch_7 + 1])
test_loss_curve_w8, = plt.plot(list(range(starting_epoch, end_epoch_8 + 1)), test_loss_w8[starting_epoch:end_epoch_8 + 1])
test_loss_curve_w9, = plt.plot(list(range(starting_epoch, end_epoch_9 + 1)), test_loss_w9[starting_epoch:end_epoch_9 + 1])
test_loss_curve_w10, = plt.plot(list(range(starting_epoch, end_epoch_10 + 1)), test_loss_w10[starting_epoch:end_epoch_10 + 1])


# test_loss_curve, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss[starting_epoch:end_epoch])
# test_loss_curve_1, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_1[starting_epoch:end_epoch])
# test_loss_curve_2, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_2[starting_epoch:end_epoch])
# test_loss_curve_3, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_3[starting_epoch:end_epoch])
# test_loss_curve_4, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_4[starting_epoch:end_epoch])
# test_loss_curve_5, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_5[starting_epoch:end_epoch])

leg = plt.legend([test_loss_curve_w1,
            test_loss_curve_w2,
            test_loss_curve_w3,
            test_loss_curve_w4,
            test_loss_curve_w5,
            test_loss_curve_w6,
            test_loss_curve_w7,
            test_loss_curve_w8,
            test_loss_curve_w9,
            test_loss_curve_w10], ['Size 1',
                                    'Size 2',
                                    'Size 3',
                                    'Size 4',
                                    'Size 5',
                                    'Size 6',
                                    'Size 7',
                                    'Size 8',
                                    'Size 9',
                                    'Size 10'], prop={'size': 16}, ncol=2)

for legobj in leg.legendHandles:
    legobj.set_linewidth(4.0)
    
plt.grid()
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("MSE Loss", fontsize=18)

# %%
# test 1 dataset learning curve, test 1 will be used as validation data set
test_loss_w1 = np.load('1600/with_normalization_with_earlystop/window_1/test_loss_1.npy')
test_loss_w2 = np.load('1600/with_normalization_with_earlystop/window_2/test_loss_1.npy')
test_loss_w3 = np.load('1600/with_normalization_with_earlystop/window_3/test_loss_1.npy')
test_loss_w4 = np.load('1600/with_normalization_with_earlystop/window_4/test_loss_1.npy')
test_loss_w5 = np.load('1600/with_normalization_with_earlystop/window_5/test_loss_1.npy')
test_loss_w6 = np.load('1600/with_normalization_with_earlystop/window_6/test_loss_1.npy')
test_loss_w7 = np.load('1600/with_normalization_with_earlystop/window_7/test_loss_1.npy')
test_loss_w8 = np.load('1600/with_normalization_with_earlystop/window_8/test_loss_1.npy')
test_loss_w9 = np.load('1600/with_normalization_with_earlystop/window_9/test_loss_1.npy')
test_loss_w10 = np.load('1600/with_normalization_with_earlystop/window_10/test_loss_1.npy')
# test_loss_w5 = np.load('1600/window_5/test_loss.npy', np.asarray(test_loss))

file = open('model/with_early_stop_after_400/model_w_1.txt', 'r')
end_epoch_1 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model/with_early_stop_after_400/model_w_2.txt', 'r')
end_epoch_2 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model/with_early_stop_after_400/model_w_3.txt', 'r')
end_epoch_3 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model/with_early_stop_after_400/model_w_4.txt', 'r')
end_epoch_4 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model/with_early_stop_after_400/model_w_5.txt', 'r')
end_epoch_5 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model/with_early_stop_after_400/model_w_6.txt', 'r')
end_epoch_6 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model/with_early_stop_after_400/model_w_7.txt', 'r')
end_epoch_7 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model/with_early_stop_after_400/model_w_8.txt', 'r')
end_epoch_8 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model/with_early_stop_after_400/model_w_9.txt', 'r')
end_epoch_9 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model/with_early_stop_after_400/model_w_10.txt', 'r')
end_epoch_10 = int(file.readlines()[0].split(' ')[-1])
file.close()


starting_epoch = 100
# end_epoch = 1600
plt.figure(figsize=(12,8))

# test_loss_curve_w1_all, = plt.plot(list(range(starting_epoch, len(test_loss_w1))), test_loss_w1[starting_epoch:])
# test_loss_curve_w2_all, = plt.plot(list(range(starting_epoch, len(test_loss_w2))), test_loss_w2[starting_epoch:])
# test_loss_curve_w3_all, = plt.plot(list(range(starting_epoch, len(test_loss_w3))), test_loss_w3[starting_epoch:])
# test_loss_curve_w4_all, = plt.plot(list(range(starting_epoch, len(test_loss_w4))), test_loss_w4[starting_epoch:])
# test_loss_curve_w5_all, = plt.plot(list(range(starting_epoch, len(test_loss_w5))), test_loss_w5[starting_epoch:])
# test_loss_curve_w6_all, = plt.plot(list(range(starting_epoch, len(test_loss_w6))), test_loss_w6[starting_epoch:])
# test_loss_curve_w7_all, = plt.plot(list(range(starting_epoch, len(test_loss_w7))), test_loss_w7[starting_epoch:])
# test_loss_curve_w8_all, = plt.plot(list(range(starting_epoch, len(test_loss_w8))), test_loss_w8[starting_epoch:])
# test_loss_curve_w9_all, = plt.plot(list(range(starting_epoch, len(test_loss_w9))), test_loss_w9[starting_epoch:])
test_loss_curve_w10_all, = plt.plot(list(range(starting_epoch, len(test_loss_w10))), test_loss_w10[starting_epoch:])

# test_loss_curve_w1, = plt.plot(list(range(starting_epoch, end_epoch_1 + 1)), test_loss_w1[starting_epoch:end_epoch_1 + 1])
# test_loss_curve_w2, = plt.plot(list(range(starting_epoch, end_epoch_2 + 1)), test_loss_w2[starting_epoch:end_epoch_2 + 1])
# test_loss_curve_w3, = plt.plot(list(range(starting_epoch, end_epoch_3 + 1)), test_loss_w3[starting_epoch:end_epoch_3 + 1])
# test_loss_curve_w4, = plt.plot(list(range(starting_epoch, end_epoch_4 + 1)), test_loss_w4[starting_epoch:end_epoch_4 + 1])
# test_loss_curve_w5, = plt.plot(list(range(starting_epoch, end_epoch_5 + 1)), test_loss_w5[starting_epoch:end_epoch_5 + 1])
# test_loss_curve_w6, = plt.plot(list(range(starting_epoch, end_epoch_6 + 1)), test_loss_w6[starting_epoch:end_epoch_6 + 1])
# test_loss_curve_w7, = plt.plot(list(range(starting_epoch, end_epoch_7 + 1)), test_loss_w7[starting_epoch:end_epoch_7 + 1])
# test_loss_curve_w8, = plt.plot(list(range(starting_epoch, end_epoch_8 + 1)), test_loss_w8[starting_epoch:end_epoch_8 + 1])
# test_loss_curve_w9, = plt.plot(list(range(starting_epoch, end_epoch_9 + 1)), test_loss_w9[starting_epoch:end_epoch_9 + 1])
test_loss_curve_w10, = plt.plot(list(range(starting_epoch, end_epoch_10 + 1)), test_loss_w10[starting_epoch:end_epoch_10 + 1])




leg = plt.legend([test_loss_curve_w3,
            test_loss_curve_w3_all], ['Size 1',
                                    'Size 1 all'], prop={'size': 16}, ncol=2)

for legobj in leg.legendHandles:
    legobj.set_linewidth(4.0)
    
plt.grid()
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("MSE Loss", fontsize=18)

# %%
end_epoch

# %%
# test 1 dataset learning curve, test 1 will be used as validation data set
test_loss_w1 = np.load('1600_v2/without_normalization_with_earlystop/window_1/test_loss_3.npy')
test_loss_w2 = np.load('1600_v2/without_normalization_with_earlystop/window_2/test_loss_3.npy')
test_loss_w3 = np.load('1600_v2/without_normalization_with_earlystop/window_3/test_loss_3.npy')
test_loss_w4 = np.load('1600_v2/without_normalization_with_earlystop/window_4/test_loss_3.npy')
test_loss_w5 = np.load('1600_v2/without_normalization_with_earlystop/window_5/test_loss_3.npy')
test_loss_w6 = np.load('1600_v2/without_normalization_with_earlystop/window_6/test_loss_3.npy')
test_loss_w7 = np.load('1600_v2/without_normalization_with_earlystop/window_7/test_loss_3.npy')
test_loss_w8 = np.load('1600_v2/without_normalization_with_earlystop/window_8/test_loss_3.npy')
test_loss_w9 = np.load('1600_v2/without_normalization_with_earlystop/window_9/test_loss_3.npy')
test_loss_w10 = np.load('1600_v2/without_normalization_with_earlystop/window_10/test_loss_3.npy')
# test_loss_w5 = np.load('1600/window_5/test_loss.npy', np.asarray(test_loss))

file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_1.txt', 'r')
end_epoch_1 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_2.txt', 'r')
end_epoch_2 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_3.txt', 'r')
end_epoch_3 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_4.txt', 'r')
end_epoch_4 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_5.txt', 'r')
end_epoch_5 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_6.txt', 'r')
end_epoch_6 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_7.txt', 'r')
end_epoch_7 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_8.txt', 'r')
end_epoch_8 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_9.txt', 'r')
end_epoch_9 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_10.txt', 'r')
end_epoch_10 = int(file.readlines()[0].split(' ')[-1])
file.close()


starting_epoch = 10
# end_epoch = 1600
plt.figure(figsize=(12,8))
test_loss_curve_w1, = plt.plot(list(range(starting_epoch, end_epoch_1 + 1)), test_loss_w1[starting_epoch:end_epoch_1 + 1])
test_loss_curve_w2, = plt.plot(list(range(starting_epoch, end_epoch_2 + 1)), test_loss_w2[starting_epoch:end_epoch_2 + 1])
test_loss_curve_w3, = plt.plot(list(range(starting_epoch, end_epoch_3 + 1)), test_loss_w3[starting_epoch:end_epoch_3 + 1])
test_loss_curve_w4, = plt.plot(list(range(starting_epoch, end_epoch_4 + 1)), test_loss_w4[starting_epoch:end_epoch_4 + 1])
test_loss_curve_w5, = plt.plot(list(range(starting_epoch, end_epoch_5 + 1)), test_loss_w5[starting_epoch:end_epoch_5 + 1])
test_loss_curve_w6, = plt.plot(list(range(starting_epoch, end_epoch_6 + 1)), test_loss_w6[starting_epoch:end_epoch_6 + 1])
test_loss_curve_w7, = plt.plot(list(range(starting_epoch, end_epoch_7 + 1)), test_loss_w7[starting_epoch:end_epoch_7 + 1])
test_loss_curve_w8, = plt.plot(list(range(starting_epoch, end_epoch_8 + 1)), test_loss_w8[starting_epoch:end_epoch_8 + 1])
test_loss_curve_w9, = plt.plot(list(range(starting_epoch, end_epoch_9 + 1)), test_loss_w9[starting_epoch:end_epoch_9 + 1])
test_loss_curve_w10, = plt.plot(list(range(starting_epoch, end_epoch_10 + 1)), test_loss_w10[starting_epoch:end_epoch_10 + 1])


# test_loss_curve, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss[starting_epoch:end_epoch])
# test_loss_curve_1, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_1[starting_epoch:end_epoch])
# test_loss_curve_2, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_2[starting_epoch:end_epoch])
# test_loss_curve_3, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_3[starting_epoch:end_epoch])
# test_loss_curve_4, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_4[starting_epoch:end_epoch])
# test_loss_curve_5, = plt.plot(list(range(starting_epoch, end_epoch)), test_loss_5[starting_epoch:end_epoch])

leg = plt.legend([test_loss_curve_w1,
            test_loss_curve_w2,
            test_loss_curve_w3,
            test_loss_curve_w4,
            test_loss_curve_w5,
            test_loss_curve_w6,
            test_loss_curve_w7,
            test_loss_curve_w8,
            test_loss_curve_w9,
            test_loss_curve_w10], ['Size 1',
                                    'Size 2',
                                    'Size 3',
                                    'Size 4',
                                    'Size 5',
                                    'Size 6',
                                    'Size 7',
                                    'Size 8',
                                    'Size 9',
                                    'Size 10'], prop={'size': 16}, ncol=2)

for legobj in leg.legendHandles:
    legobj.set_linewidth(4.0)
    
plt.grid()
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("MSE Loss", fontsize=18)

# %%
# test 1 dataset learning curve, test 1 will be used as validation data set
test_loss_w1 = np.load('1600_v2/without_normalization_with_earlystop/window_1/test_loss_3.npy')
test_loss_w2 = np.load('1600_v2/without_normalization_with_earlystop/window_2/test_loss_3.npy')
test_loss_w3 = np.load('1600_v2/without_normalization_with_earlystop/window_3/test_loss_3.npy')
test_loss_w4 = np.load('1600_v2/without_normalization_with_earlystop/window_4/test_loss_3.npy')
test_loss_w5 = np.load('1600_v2/without_normalization_with_earlystop/window_5/test_loss_3.npy')
test_loss_w6 = np.load('1600_v2/without_normalization_with_earlystop/window_6/test_loss_3.npy')
test_loss_w7 = np.load('1600_v2/without_normalization_with_earlystop/window_7/test_loss_3.npy')
test_loss_w8 = np.load('1600_v2/without_normalization_with_earlystop/window_8/test_loss_3.npy')
test_loss_w9 = np.load('1600_v2/without_normalization_with_earlystop/window_9/test_loss_3.npy')
test_loss_w10 = np.load('1600_v2/without_normalization_with_earlystop/window_10/test_loss_3.npy')
# test_loss_w5 = np.load('1600/window_5/test_loss.npy', np.asarray(test_loss))

file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_1.txt', 'r')
end_epoch_1 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_2.txt', 'r')
end_epoch_2 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_3.txt', 'r')
end_epoch_3 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_4.txt', 'r')
end_epoch_4 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_5.txt', 'r')
end_epoch_5 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_6.txt', 'r')
end_epoch_6 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_7.txt', 'r')
end_epoch_7 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_8.txt', 'r')
end_epoch_8 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_9.txt', 'r')
end_epoch_9 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_w_10.txt', 'r')
end_epoch_10 = int(file.readlines()[0].split(' ')[-1])
file.close()


starting_epoch = 10
# end_epoch = 1600
plt.figure(figsize=(12,8))

# test_loss_curve_w1_all, = plt.plot(list(range(starting_epoch, len(test_loss_w1))), test_loss_w1[starting_epoch:])
# test_loss_curve_w2_all, = plt.plot(list(range(starting_epoch, len(test_loss_w2))), test_loss_w2[starting_epoch:])
test_loss_curve_w3_all, = plt.plot(list(range(starting_epoch, len(test_loss_w3))), test_loss_w3[starting_epoch:])
# test_loss_curve_w4_all, = plt.plot(list(range(starting_epoch, len(test_loss_w4))), test_loss_w4[starting_epoch:])
# test_loss_curve_w5_all, = plt.plot(list(range(starting_epoch, len(test_loss_w5))), test_loss_w5[starting_epoch:])
# test_loss_curve_w6_all, = plt.plot(list(range(starting_epoch, len(test_loss_w6))), test_loss_w6[starting_epoch:])
# test_loss_curve_w7_all, = plt.plot(list(range(starting_epoch, len(test_loss_w7))), test_loss_w7[starting_epoch:])
# test_loss_curve_w8_all, = plt.plot(list(range(starting_epoch, len(test_loss_w8))), test_loss_w8[starting_epoch:])
# test_loss_curve_w9_all, = plt.plot(list(range(starting_epoch, len(test_loss_w9))), test_loss_w9[starting_epoch:])
# test_loss_curve_w10_all, = plt.plot(list(range(starting_epoch, len(test_loss_w10))), test_loss_w10[starting_epoch:])

# test_loss_curve_w1, = plt.plot(list(range(starting_epoch, end_epoch_1 + 1)), test_loss_w1[starting_epoch:end_epoch_1 + 1])
# test_loss_curve_w2, = plt.plot(list(range(starting_epoch, end_epoch_2 + 1)), test_loss_w2[starting_epoch:end_epoch_2 + 1])
test_loss_curve_w3, = plt.plot(list(range(starting_epoch, end_epoch_3 + 1)), test_loss_w3[starting_epoch:end_epoch_3 + 1])
# test_loss_curve_w4, = plt.plot(list(range(starting_epoch, end_epoch_4 + 1)), test_loss_w4[starting_epoch:end_epoch_4 + 1])
# test_loss_curve_w5, = plt.plot(list(range(starting_epoch, end_epoch_5 + 1)), test_loss_w5[starting_epoch:end_epoch_5 + 1])
# test_loss_curve_w6, = plt.plot(list(range(starting_epoch, end_epoch_6 + 1)), test_loss_w6[starting_epoch:end_epoch_6 + 1])
# test_loss_curve_w7, = plt.plot(list(range(starting_epoch, end_epoch_7 + 1)), test_loss_w7[starting_epoch:end_epoch_7 + 1])
# test_loss_curve_w8, = plt.plot(list(range(starting_epoch, end_epoch_8 + 1)), test_loss_w8[starting_epoch:end_epoch_8 + 1])
# test_loss_curve_w9, = plt.plot(list(range(starting_epoch, end_epoch_9 + 1)), test_loss_w9[starting_epoch:end_epoch_9 + 1])
# test_loss_curve_w10, = plt.plot(list(range(starting_epoch, end_epoch_10 + 1)), test_loss_w10[starting_epoch:end_epoch_10 + 1])




leg = plt.legend([test_loss_curve_w1,
            test_loss_curve_w1_all], ['Size 1',
                                    'Size 1 all'], prop={'size': 16}, ncol=2)

for legobj in leg.legendHandles:
    legobj.set_linewidth(4.0)
    
plt.grid()
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("MSE Loss", fontsize=18)

# %%
# test 1 dataset learning curve, test 1 will be used as validation data set
test_loss_w1 = np.load('1600_v3/without_normalization_with_earlystop/window_1/test_loss_3.npy')
test_loss_w2 = np.load('1600_v3/without_normalization_with_earlystop/window_2/test_loss_3.npy')
test_loss_w3 = np.load('1600_v3/without_normalization_with_earlystop/window_3/test_loss_3.npy')
test_loss_w4 = np.load('1600_v3/without_normalization_with_earlystop/window_4/test_loss_3.npy')
test_loss_w5 = np.load('1600_v3/without_normalization_with_earlystop/window_5/test_loss_3.npy')
test_loss_w6 = np.load('1600_v3/without_normalization_with_earlystop/window_6/test_loss_3.npy')
test_loss_w7 = np.load('1600_v3/without_normalization_with_earlystop/window_7/test_loss_3.npy')
test_loss_w8 = np.load('1600_v3/without_normalization_with_earlystop/window_8/test_loss_3.npy')
test_loss_w9 = np.load('1600_v3/without_normalization_with_earlystop/window_9/test_loss_3.npy')
test_loss_w10 = np.load('1600_v3/without_normalization_with_earlystop/window_10/test_loss_3.npy')

file = open('model_v3/with_early_stop_after_400_without_normalization/model_w_1.txt', 'r')
end_epoch_1 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v3/with_early_stop_after_400_without_normalization/model_w_2.txt', 'r')
end_epoch_2 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v3/with_early_stop_after_400_without_normalization/model_w_3.txt', 'r')
end_epoch_3 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v3/with_early_stop_after_400_without_normalization/model_w_4.txt', 'r')
end_epoch_4 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v3/with_early_stop_after_400_without_normalization/model_w_5.txt', 'r')
end_epoch_5 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v3/with_early_stop_after_400_without_normalization/model_w_6.txt', 'r')
end_epoch_6 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v3/with_early_stop_after_400_without_normalization/model_w_7.txt', 'r')
end_epoch_7 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v3/with_early_stop_after_400_without_normalization/model_w_8.txt', 'r')
end_epoch_8 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v3/with_early_stop_after_400_without_normalization/model_w_9.txt', 'r')
end_epoch_9 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v3/with_early_stop_after_400_without_normalization/model_w_10.txt', 'r')
end_epoch_10 = int(file.readlines()[0].split(' ')[-1])
file.close()

starting_epoch = 10
# end_epoch = 1600
plt.figure(figsize=(12,8))

test_loss_curve_w1_all, = plt.plot(list(range(starting_epoch, len(test_loss_w1))), test_loss_w1[starting_epoch:])
test_loss_curve_w2_all, = plt.plot(list(range(starting_epoch, len(test_loss_w2))), test_loss_w2[starting_epoch:])
test_loss_curve_w3_all, = plt.plot(list(range(starting_epoch, len(test_loss_w3))), test_loss_w3[starting_epoch:])
test_loss_curve_w4_all, = plt.plot(list(range(starting_epoch, len(test_loss_w4))), test_loss_w4[starting_epoch:])
test_loss_curve_w5_all, = plt.plot(list(range(starting_epoch, len(test_loss_w5))), test_loss_w5[starting_epoch:])
test_loss_curve_w6_all, = plt.plot(list(range(starting_epoch, len(test_loss_w6))), test_loss_w6[starting_epoch:])
test_loss_curve_w7_all, = plt.plot(list(range(starting_epoch, len(test_loss_w7))), test_loss_w7[starting_epoch:])
test_loss_curve_w8_all, = plt.plot(list(range(starting_epoch, len(test_loss_w8))), test_loss_w8[starting_epoch:])
test_loss_curve_w9_all, = plt.plot(list(range(starting_epoch, len(test_loss_w9))), test_loss_w9[starting_epoch:])
test_loss_curve_w10_all, = plt.plot(list(range(starting_epoch, len(test_loss_w10))), test_loss_w10[starting_epoch:])

# test_loss_curve_w1, = plt.plot(list(range(starting_epoch, end_epoch_1 + 1)), test_loss_w1[starting_epoch:end_epoch_1 + 1])
# test_loss_curve_w2, = plt.plot(list(range(starting_epoch, end_epoch_2 + 1)), test_loss_w2[starting_epoch:end_epoch_2 + 1])
# test_loss_curve_w3, = plt.plot(list(range(starting_epoch, end_epoch_3 + 1)), test_loss_w3[starting_epoch:end_epoch_3 + 1])
# test_loss_curve_w4, = plt.plot(list(range(starting_epoch, end_epoch_4 + 1)), test_loss_w4[starting_epoch:end_epoch_4 + 1])
# test_loss_curve_w5, = plt.plot(list(range(starting_epoch, end_epoch_5 + 1)), test_loss_w5[starting_epoch:end_epoch_5 + 1])
# test_loss_curve_w6, = plt.plot(list(range(starting_epoch, end_epoch_6 + 1)), test_loss_w6[starting_epoch:end_epoch_6 + 1])
# test_loss_curve_w7, = plt.plot(list(range(starting_epoch, end_epoch_7 + 1)), test_loss_w7[starting_epoch:end_epoch_7 + 1])
# test_loss_curve_w8, = plt.plot(list(range(starting_epoch, end_epoch_8 + 1)), test_loss_w8[starting_epoch:end_epoch_8 + 1])
# test_loss_curve_w9, = plt.plot(list(range(starting_epoch, end_epoch_9 + 1)), test_loss_w9[starting_epoch:end_epoch_9 + 1])
# test_loss_curve_w10, = plt.plot(list(range(starting_epoch, end_epoch_10 + 1)), test_loss_w10[starting_epoch:end_epoch_10 + 1])




leg = plt.legend([test_loss_curve_w1,
            test_loss_curve_w1_all], ['Size 1',
                                    'Size 1 all'], prop={'size': 16}, ncol=2)

for legobj in leg.legendHandles:
    legobj.set_linewidth(4.0)
    
plt.grid()
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("MSE Loss", fontsize=18)

# %%
# test 1 dataset learning curve, test 1 will be used as validation data set
test_loss_w1 = np.load('1600_v3/without_normalization_with_earlystop/window_3/test_loss_1.npy')
test_loss_w2 = np.load('1600_v3/without_normalization_with_earlystop/window_3/test_loss_2.npy')
test_loss_w3 = np.load('1600_v3/without_normalization_with_earlystop/window_3/test_loss_3.npy')
test_loss_w4 = np.load('1600_v3/without_normalization_with_earlystop/window_3/test_loss_4.npy')
test_loss_w5 = np.load('1600_v3/without_normalization_with_earlystop/window_3/test_loss_5.npy')

file = open('model_v3/with_early_stop_after_400_without_normalization/model_w_3.txt', 'r')
end_epoch_3 = int(file.readlines()[0].split(' ')[-1])
file.close()

starting_epoch = 10
# end_epoch = 1600
plt.figure(figsize=(12,8))
'''
test_loss_curve_w1_all, = plt.plot(list(range(starting_epoch, len(test_loss_w1))), test_loss_w1[starting_epoch:])
test_loss_curve_w2_all, = plt.plot(list(range(starting_epoch, len(test_loss_w2))), test_loss_w2[starting_epoch:])
test_loss_curve_w3_all, = plt.plot(list(range(starting_epoch, len(test_loss_w3))), test_loss_w3[starting_epoch:])
test_loss_curve_w4_all, = plt.plot(list(range(starting_epoch, len(test_loss_w4))), test_loss_w4[starting_epoch:])
test_loss_curve_w5_all, = plt.plot(list(range(starting_epoch, len(test_loss_w5))), test_loss_w5[starting_epoch:])
test_loss_curve_w6_all, = plt.plot(list(range(starting_epoch, len(test_loss_w6))), test_loss_w6[starting_epoch:])
test_loss_curve_w7_all, = plt.plot(list(range(starting_epoch, len(test_loss_w7))), test_loss_w7[starting_epoch:])
test_loss_curve_w8_all, = plt.plot(list(range(starting_epoch, len(test_loss_w8))), test_loss_w8[starting_epoch:])
test_loss_curve_w9_all, = plt.plot(list(range(starting_epoch, len(test_loss_w9))), test_loss_w9[starting_epoch:])
test_loss_curve_w10_all, = plt.plot(list(range(starting_epoch, len(test_loss_w10))), test_loss_w10[starting_epoch:])
'''
test_loss_curve_w1, = plt.plot(list(range(starting_epoch, end_epoch_3 + 1)), test_loss_w1[starting_epoch:end_epoch_3 + 1])
test_loss_curve_w2, = plt.plot(list(range(starting_epoch, end_epoch_3 + 1)), test_loss_w2[starting_epoch:end_epoch_3 + 1])
test_loss_curve_w3, = plt.plot(list(range(starting_epoch, end_epoch_3 + 1)), test_loss_w3[starting_epoch:end_epoch_3 + 1])
test_loss_curve_w4, = plt.plot(list(range(starting_epoch, end_epoch_3 + 1)), test_loss_w4[starting_epoch:end_epoch_3 + 1])
test_loss_curve_w5, = plt.plot(list(range(starting_epoch, end_epoch_3 + 1)), test_loss_w5[starting_epoch:end_epoch_3 + 1])


leg = plt.legend([test_loss_curve_w1,
                  test_loss_curve_w2,
                  test_loss_curve_w3,
                  test_loss_curve_w4,
                  test_loss_curve_w5], ['test 1',
                                        'test 2',
                                        'test 3',
                                        'test 4',
                                        'test 5',], prop={'size': 16}, ncol=2)

for legobj in leg.legendHandles:
    legobj.set_linewidth(4.0)
    
plt.grid()
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("MSE Loss", fontsize=18)

# %%
print("test 1 mse loss: ", test_loss_w1[end_epoch_3])
print("test 2 mse loss: ", test_loss_w2[end_epoch_3])
print("test 3 mse loss: ", test_loss_w3[end_epoch_3])
print("test 4 mse loss: ", test_loss_w4[end_epoch_3])
print("test 5 mse loss: ", test_loss_w5[end_epoch_3])

# %%
# test 1 dataset learning curve, test 1 will be used as validation data set
train_loss_w1 = np.load('1600_v3/without_normalization_with_earlystop/window_3/train_loss.npy')
test_loss_w1 = np.load('1600_v3/without_normalization_with_earlystop/window_3/test_loss_1.npy')
test_loss_w2 = np.load('1600_v3/without_normalization_with_earlystop/window_3/test_loss_2.npy')
test_loss_w3 = np.load('1600_v3/without_normalization_with_earlystop/window_3/test_loss_3.npy')
test_loss_w4 = np.load('1600_v3/without_normalization_with_earlystop/window_3/test_loss_4.npy')
test_loss_w5 = np.load('1600_v3/without_normalization_with_earlystop/window_3/test_loss_5.npy')

file = open('model_v3/with_early_stop_after_400_without_normalization/model_w_3.txt', 'r')
end_epoch_3 = int(file.readlines()[0].split(' ')[-1])
file.close()

starting_epoch = 10
# end_epoch = 1600
plt.figure(figsize=(12,8))
'''
test_loss_curve_w1_all, = plt.plot(list(range(starting_epoch, len(test_loss_w1))), test_loss_w1[starting_epoch:])
test_loss_curve_w2_all, = plt.plot(list(range(starting_epoch, len(test_loss_w2))), test_loss_w2[starting_epoch:])
test_loss_curve_w3_all, = plt.plot(list(range(starting_epoch, len(test_loss_w3))), test_loss_w3[starting_epoch:])
test_loss_curve_w4_all, = plt.plot(list(range(starting_epoch, len(test_loss_w4))), test_loss_w4[starting_epoch:])
test_loss_curve_w5_all, = plt.plot(list(range(starting_epoch, len(test_loss_w5))), test_loss_w5[starting_epoch:])
test_loss_curve_w6_all, = plt.plot(list(range(starting_epoch, len(test_loss_w6))), test_loss_w6[starting_epoch:])
test_loss_curve_w7_all, = plt.plot(list(range(starting_epoch, len(test_loss_w7))), test_loss_w7[starting_epoch:])
test_loss_curve_w8_all, = plt.plot(list(range(starting_epoch, len(test_loss_w8))), test_loss_w8[starting_epoch:])
test_loss_curve_w9_all, = plt.plot(list(range(starting_epoch, len(test_loss_w9))), test_loss_w9[starting_epoch:])
test_loss_curve_w10_all, = plt.plot(list(range(starting_epoch, len(test_loss_w10))), test_loss_w10[starting_epoch:])
'''
train_loss_curve_w1, = plt.plot(list(range(starting_epoch, end_epoch_3 + 1)), train_loss_w1[starting_epoch:end_epoch_3 + 1])
# test_loss_curve_w1, = plt.plot(list(range(starting_epoch, end_epoch_3 + 1)), test_loss_w1[starting_epoch:end_epoch_3 + 1])
# test_loss_curve_w2, = plt.plot(list(range(starting_epoch, end_epoch_3 + 1)), test_loss_w2[starting_epoch:end_epoch_3 + 1])
# test_loss_curve_w3, = plt.plot(list(range(starting_epoch, end_epoch_3 + 1)), test_loss_w3[starting_epoch:end_epoch_3 + 1])
# test_loss_curve_w4, = plt.plot(list(range(starting_epoch, end_epoch_3 + 1)), test_loss_w4[starting_epoch:end_epoch_3 + 1])
# test_loss_curve_w5, = plt.plot(list(range(starting_epoch, end_epoch_3 + 1)), test_loss_w5[starting_epoch:end_epoch_3 + 1])


leg = plt.legend([train_loss_curve_w1], ['test 1'], prop={'size': 16}, ncol=2)

for legobj in leg.legendHandles:
    legobj.set_linewidth(4.0)
    
plt.grid()
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("MSE Loss", fontsize=18)
# Out:
# Text(0, 0.5, 'MSE Loss')

# %%
train_loss_w1[end_epoch_3]
# Out:
# 0.0010108687153357703

# %%
end_epoch_3
# Out:
# 3011
