# %% [markdown]
# # visuialy analysis training results by see the learning curve

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import interactive
interactive(True)
# %matplotlib qt

# %%
# training learning curve
train_loss_ng1 = np.load('4000_v2/without_normalization_with_earlystop/ng_1/train_loss.npy')
train_loss_ng2 = np.load('4000_v2/without_normalization_with_earlystop/ng_2/train_loss.npy')
train_loss_ng3 = np.load('4000_v2/without_normalization_with_earlystop/ng_3/train_loss.npy')
train_loss_ng4 = np.load('4000_v2/without_normalization_with_earlystop/ng_4/train_loss.npy')
train_loss_ng5 = np.load('4000_v2/without_normalization_with_earlystop/ng_5/train_loss.npy')
train_loss_ng6 = np.load('4000_v2/without_normalization_with_earlystop/ng_6/train_loss.npy')
train_loss_ng7 = np.load('4000_v2/without_normalization_with_earlystop/ng_7/train_loss.npy')
train_loss_ng8 = np.load('4000_v2/without_normalization_with_earlystop/ng_8/train_loss.npy')
train_loss_ng9 = np.load('4000_v2/without_normalization_with_earlystop/ng_9/train_loss.npy')
train_loss_ng10 = np.load('4000_v2/without_normalization_with_earlystop/ng_10/train_loss.npy')

file = open('model_v2/with_early_stop_after_400_without_normalization/model_ng_3.txt', 'r')
end_epoch_3 = int(file.readlines()[0].split(' ')[-1])
file.close()

starting_epoch = 0
end_epoch = 1600
# train_loss_curve_w1, = plt.plot(list(range(starting_epoch, end_epoch)), train_loss_w1[starting_epoch:end_epoch])
train_loss_curve_ng1, = plt.plot(train_loss_ng1[starting_epoch:])
train_loss_curve_ng2, = plt.plot(train_loss_ng2[starting_epoch:])
train_loss_curve_ng3, = plt.plot(train_loss_ng3[starting_epoch:])
train_loss_curve_ng4, = plt.plot(train_loss_ng4[starting_epoch:])
train_loss_curve_ng5, = plt.plot(train_loss_ng5[starting_epoch:])
train_loss_curve_ng6, = plt.plot(train_loss_ng6[starting_epoch:])
train_loss_curve_ng7, = plt.plot(train_loss_ng7[starting_epoch:])
train_loss_curve_ng8, = plt.plot(train_loss_ng8[starting_epoch:])
train_loss_curve_ng9, = plt.plot(train_loss_ng9[starting_epoch:])
train_loss_curve_ng10, = plt.plot(train_loss_ng10[starting_epoch:])



plt.legend([train_loss_curve_ng1,
            train_loss_curve_ng2,
            train_loss_curve_ng3,
            train_loss_curve_ng4,
            train_loss_curve_ng5,
            train_loss_curve_ng6,
            train_loss_curve_ng7,
            train_loss_curve_ng8,
            train_loss_curve_ng9,
            train_loss_curve_ng10], ['Train Loss ng 1',
                                     'Train Loss ng 2',
                                     'Train Loss ng 3',
                                     'Train Loss ng 4',
                                     'Train Loss ng 5',
                                     'Train Loss ng 6',
                                     'Train Loss ng 7',
                                     'Train Loss ng 8',
                                     'Train Loss ng 9',
                                     'Train Loss ng 10'])
plt.grid()
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
# Out:
# Text(0, 0.5, 'MSE Loss')

# %%
# test 3 dataset learning curve, test 1 will be used as validation data set
test_loss_ng1 = np.load('4000_v2/without_normalization_with_earlystop/ng_1/valid_loss.npy')
# delete last nan element
test_loss_ng1 = test_loss_ng1[:-1]
test_loss_ng2 = np.load('4000_v2/without_normalization_with_earlystop/ng_2/valid_loss.npy')
test_loss_ng3 = np.load('4000_v2/without_normalization_with_earlystop/ng_3/valid_loss.npy')
test_loss_ng4 = np.load('4000_v2/without_normalization_with_earlystop/ng_4/valid_loss.npy')
test_loss_ng5 = np.load('4000_v2/without_normalization_with_earlystop/ng_5/valid_loss.npy')
test_loss_ng6 = np.load('4000_v2/without_normalization_with_earlystop/ng_6/valid_loss.npy')
test_loss_ng7 = np.load('4000_v2/without_normalization_with_earlystop/ng_7/valid_loss.npy')
test_loss_ng8 = np.load('4000_v2/without_normalization_with_earlystop/ng_8/valid_loss.npy')
test_loss_ng9 = np.load('4000_v2/without_normalization_with_earlystop/ng_9/valid_loss.npy')
test_loss_ng10 = np.load('4000_v2/without_normalization_with_earlystop/ng_10/valid_loss.npy')

file = open('model_v2/with_early_stop_after_400_without_normalization/model_ng_1.txt', 'r')
end_epoch_1 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_ng_2.txt', 'r')
end_epoch_2 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_ng_3.txt', 'r')
end_epoch_3 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_ng_4.txt', 'r')
end_epoch_4 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_ng_5.txt', 'r')
end_epoch_5 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_ng_6.txt', 'r')
end_epoch_6 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_ng_7.txt', 'r')
end_epoch_7 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_ng_8.txt', 'r')
end_epoch_8 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_ng_9.txt', 'r')
end_epoch_9 = int(file.readlines()[0].split(' ')[-1])
file.close()
file = open('model_v2/with_early_stop_after_400_without_normalization/model_ng_10.txt', 'r')
end_epoch_10 = int(file.readlines()[0].split(' ')[-1])
file.close()

starting_epoch = 0
# end_epoch = 1600
plt.figure(figsize=(12,8))

# test_loss_curve_ng1_all, = plt.plot(list(range(starting_epoch, len(test_loss_ng1))), test_loss_ng1[starting_epoch:])
# test_loss_curve_ng2_all, = plt.plot(list(range(starting_epoch, len(test_loss_ng2))), test_loss_ng2[starting_epoch:])
# test_loss_curve_ng3_all, = plt.plot(list(range(starting_epoch, len(test_loss_ng3))), test_loss_ng3[starting_epoch:])
# test_loss_curve_ng4_all, = plt.plot(list(range(starting_epoch, len(test_loss_ng4))), test_loss_ng4[starting_epoch:])
# test_loss_curve_ng5_all, = plt.plot(list(range(starting_epoch, len(test_loss_ng5))), test_loss_ng5[starting_epoch:])
# test_loss_curve_ng6_all, = plt.plot(list(range(starting_epoch, len(test_loss_ng6))), test_loss_ng6[starting_epoch:])
# test_loss_curve_ng7_all, = plt.plot(list(range(starting_epoch, len(test_loss_ng7))), test_loss_ng7[starting_epoch:])
test_loss_curve_ng8_all, = plt.plot(list(range(starting_epoch, len(test_loss_ng8))), test_loss_ng8[starting_epoch:])
test_loss_curve_ng9_all, = plt.plot(list(range(starting_epoch, len(test_loss_ng9))), test_loss_ng9[starting_epoch:])
test_loss_curve_ng10_all, = plt.plot(list(range(starting_epoch, len(test_loss_ng10))), test_loss_ng10[starting_epoch:])

# test_loss_curve_ng1, = plt.plot(list(range(starting_epoch, end_epoch_1 + 1)), test_loss_ng1[starting_epoch:end_epoch_1 + 1])
# test_loss_curve_ng2, = plt.plot(list(range(starting_epoch, end_epoch_2 + 1)), test_loss_ng2[starting_epoch:end_epoch_2 + 1])
# test_loss_curve_ng3, = plt.plot(list(range(starting_epoch, end_epoch_3 + 1)), test_loss_ng3[starting_epoch:end_epoch_3 + 1])
# test_loss_curve_ng4, = plt.plot(list(range(starting_epoch, end_epoch_4 + 1)), test_loss_ng4[starting_epoch:end_epoch_4 + 1])
# test_loss_curve_ng5, = plt.plot(list(range(starting_epoch, end_epoch_5 + 1)), test_loss_ng5[starting_epoch:end_epoch_5 + 1])
# test_loss_curve_ng6, = plt.plot(list(range(starting_epoch, end_epoch_6 + 1)), test_loss_ng6[starting_epoch:end_epoch_6 + 1])
# test_loss_curve_ng7, = plt.plot(list(range(starting_epoch, end_epoch_7 + 1)), test_loss_ng7[starting_epoch:end_epoch_7 + 1])
test_loss_curve_ng8, = plt.plot(list(range(starting_epoch, end_epoch_8 + 1)), test_loss_ng8[starting_epoch:end_epoch_8 + 1])
test_loss_curve_ng9, = plt.plot(list(range(starting_epoch, end_epoch_9 + 1)), test_loss_ng9[starting_epoch:end_epoch_9 + 1])
test_loss_curve_ng10, = plt.plot(list(range(starting_epoch, end_epoch_10 + 1)), test_loss_ng10[starting_epoch:end_epoch_10 + 1])
               
    
                                    
                                    
                                    
# test_loss_curve_w1, = plt.plot(list(range(starting_epoch, end_epoch_1 + 1)), test_loss_w1[starting_epoch:end_epoch_1 + 1])
# test_loss_curve_w2, = plt.plot(list(range(starting_epoch, end_epoch_2 + 1)), test_loss_w2[starting_epoch:end_epoch_2 + 1])
# test_loss_curve_w3, = plt.plot(list(range(starting_epoch, end_epoch_3 + 1)), test_loss_w3[starting_epoch:end_epoch_3 + 1])
# test_loss_curve_w4, = plt.plot(list(range(starting_epoch, end_epoch_4 + 1)), test_loss_w4[starting_epoch:end_epoch_4 + 1])
# test_loss_curve_w5, = plt.plot(list(range(starting_epoch, end_epoch_5 + 1)), test_loss_w5[starting_epoch:end_epoch_5 + 1])
# test_loss_curve_w6, = plt.plot(list(range(starting_epoch, end_epoch_6 + 1)), test_loss_w6[starting_epoch:end_epoch_6 + 1])
# test_loss_curve_w7, = plt.plot(list(range(starting_epoch, end_epoch_7 + 1)), test_loss_w7[starting_epoch:end_epoch_7 + 1])
# test_loss_curve_w8, = plt.plot(list(range(starting_epoch, end_epoch_8 + 1)), test_loss_w8[starting_epoch:end_epoch_8 + 1])
# test_loss_curve_w9, = plt.plot(list(range(starting_epoch, end_epoch_9 + 1)), test_loss_w9[starting_epoch:end_epoch_9 + 1])
# test_loss_curve_w10, = plt.plot(list(range(starting_epoch, end_epoch_10 + 1)), test_loss_w10[starting_epoch:end_epoch_10 + 1])



'''
plt.legend([test_loss_curve_ng1_all,
            test_loss_curve_ng2_all,
            test_loss_curve_ng3_all,
            test_loss_curve_ng4_all,
            test_loss_curve_ng5_all,
            test_loss_curve_ng6_all,
            test_loss_curve_ng7_all,
            test_loss_curve_ng8_all,
            test_loss_curve_ng9_all,
            test_loss_curve_ng10_all], ['Test Loss ng 1 all',
                                     'Test Loss ng 2 all',
                                     'Test Loss ng 3 all',
                                     'Test Loss ng 4 all',
                                     'Test Loss ng 5 all',
                                     'Test Loss ng 6 all',
                                     'Test Loss ng 7 all',
                                     'Test Loss ng 8 all',
                                     'Test Loss ng 9 all',
                                     'Test Loss ng 10 all'])
'''
plt.legend([test_loss_curve_ng1,
            test_loss_curve_ng2,
            test_loss_curve_ng3,
            test_loss_curve_ng4,
            test_loss_curve_ng5,
            test_loss_curve_ng6,
            test_loss_curve_ng7,
            test_loss_curve_ng8,
            test_loss_curve_ng9,
            test_loss_curve_ng10], ['Test Loss ng 1',
                                     'Test Loss ng 2',
                                     'Test Loss ng 3',
                                     'Test Loss ng 4',
                                     'Test Loss ng 5',
                                     'Test Loss ng 6',
                                     'Test Loss ng 7',
                                     'Test Loss ng 8',
                                     'Test Loss ng 9',
                                     'Test Loss ng 10'])
    
plt.grid()
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("MSE Loss", fontsize=18)
# Out:
# Text(0, 0.5, 'MSE Loss')
